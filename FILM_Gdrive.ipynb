# %% [markdown]
# <a href="https://colab.research.google.com/github/arumajirou/-daily-test/blob/main/FILM_Gdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FILM Colab **
# フレーム補間処理方法の詳細については、githubを参照してください。
#
# ---
#
#
#
# Derrick SchultzによるGDriveとの統合強化およびその他の細かい修正。
#
# Pro/+をお持ちの方は、ぜひ「High RAM」設定をご利用ください。

# %%
#@title ##Google Driveへアクセス

import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd /content/gdrive/MyDrive
HOME='/content/gdrive/MyDrive'
# !nvidia-smi
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive
# Thu Dec 22 10:35:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#@title ##github.com/google-researchからフレーム補間のソースコードをクローン(リモートリポジトリをそのまま自分のローカル環境（自分のPC上）へ複製（コピー）する機能)する。
if not os.path.isdir(f'{HOME}/frame-interpolation'):
  # !git clone https://github.com/google-research/frame-interpolation
# %cd frame-interpolation
# Out:
# /content/gdrive/MyDrive/frame-interpolation

# %%
#@title ##FILMのインストール、google-driveから訓練済みの計算式／計算方法ダウンロード
# !pip install -r requirements.txt
if not os.path.isdir(f'{HOME}/frame-interpolation/pretrained_models'):
  # !gdown 1C1YwOo293_yrgSS8tAyFbbVcMeXxzftE -O pretrained_models-20220214T214839Z-001.zip
  # !unzip -o "pretrained_models-20220214T214839Z-001.zip"
  # !rm -rf pretrained_models-20220214T214839Z-001.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow==2.6.2 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 2)) (2.6.2)
# Requirement already satisfied: tensorflow-datasets==4.4.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: tensorflow-addons==0.15.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 4)) (0.15.0)
# Requirement already satisfied: absl-py==0.12.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: gin-config==0.5.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 6)) (0.5.0)
# Requirement already satisfied: parameterized==0.8.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 7)) (0.8.1)
# Requirement already satisfied: mediapy==1.0.3 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 8)) (1.0.3)
# Requirement already satisfied: scikit-image==0.19.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 9)) (0.19.1)
# Requirement already satisfied: apache-beam==2.34.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 10)) (2.34.0)
# Requirement already satisfied: google-cloud-bigquery-storage==1.1.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: natsort==8.1.0 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 12)) (8.1.0)
# Requirement already satisfied: gdown==4.5.4 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 13)) (4.5.4)
# Requirement already satisfied: tqdm==4.64.1 in /usr/local/lib/python3.8/dist-packages (from -r requirements.txt (line 14)) (4.64.1)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (3.19.6)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.51.1)
# Requirement already satisfied: tensorflow-estimator<2.7,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.12.1)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (0.4.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.19.5)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.6.2->-r requirements.txt (line 2)) (0.38.4)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (5.10.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (0.3.1.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (2.28.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (2.3)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (0.18.2)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons==0.15.0->-r requirements.txt (line 4)) (2.7.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from mediapy==1.0.3->-r requirements.txt (line 8)) (7.9.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from mediapy==1.0.3->-r requirements.txt (line 8)) (7.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from mediapy==1.0.3->-r requirements.txt (line 8)) (3.2.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (21.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (2.8.8)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (2022.10.10)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image==0.19.1->-r requirements.txt (line 9)) (1.7.3)
# Requirement already satisfied: avro-python3!=1.9.2,<1.10.0,>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (1.9.2.1)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (2.7.0)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (2022.6)
# Requirement already satisfied: pyarrow<6.0.0,>=0.15.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (5.0.0)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (3.8.3)
# Requirement already satisfied: oauth2client<5,>=2.0.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (4.1.3)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (1.7)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (3.13.0)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: fastavro<2,>=0.21.4 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (1.7.0)
# Requirement already satisfied: httplib2<0.20.0,>=0.8 in /usr/local/lib/python3.8/dist-packages (from apache-beam==2.34.0->-r requirements.txt (line 10)) (0.17.4)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (1.34.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown==4.5.4->-r requirements.txt (line 13)) (3.8.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown==4.5.4->-r requirements.txt (line 13)) (4.6.3)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (1.57.0)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (1.48.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->google-cloud-bigquery-storage==1.1.0->-r requirements.txt (line 11)) (4.2.4)
# Requirement already satisfied: docopt in /usr/local/lib/python3.8/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam==2.34.0->-r requirements.txt (line 10)) (0.6.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.8/dist-packages (from oauth2client<5,>=2.0.1->apache-beam==2.34.0->-r requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->scikit-image==0.19.1->-r requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (5.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow==2.6.2->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (5.7.1)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (2.0.10)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.18.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mediapy==1.0.3->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->mediapy==1.0.3->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->mediapy==1.0.3->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0->-r requirements.txt (line 3)) (1.7.1)

# %%
#@markdown ##FILM補間器の実行
#@markdown input_folderは、補間する入力フレームのフルパスです。
#@markdown この例では、クローンしたレポの中の「photos」フォルダを指しています。

input_folder = '/content/gdrive/MyDrive/frame-interpolation/photos' #@param {type:"string"}
recursion_times = 6 #@param {type:"slider", min:1, max:10, step:1}

model_path = 'pretrained_models/film_net/Style/saved_model'
# !python3 -m eval.interpolator_cli \
   --pattern $input_folder \
   --model_path $model_path \
   --times_to_interpolate $recursion_times \
   --output_video
#@markdown 補間されたフレームは{input_folder}/interpolated_framesに保存されます。

#@markdown 出力映像は{input_folder}/interpolated.mp4になります。
# Out:
# W1222 10:35:17.261681 139737941612416 environments.py:371] Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# I1222 10:35:17.261848 139737941612416 environments.py:380] Default Python SDK image for environment is apache/beam_python3.8_sdk:2.34.0
# I1222 10:35:17.284413 139737941612416 translations.py:678] ==================== <function annotate_downstream_side_inputs at 0x7f16b3703040> ====================
# I1222 10:35:17.284649 139737941612416 translations.py:678] ==================== <function fix_side_input_pcoll_coders at 0x7f16b3703160> ====================
# I1222 10:35:17.284748 139737941612416 translations.py:678] ==================== <function pack_combiners at 0x7f16b3703670> ====================
# I1222 10:35:17.284989 139737941612416 translations.py:678] ==================== <function lift_combiners at 0x7f16b3703700> ====================
# I1222 10:35:17.285078 139737941612416 translations.py:678] ==================== <function expand_sdf at 0x7f16b37038b0> ====================
# I1222 10:35:17.285159 139737941612416 translations.py:678] ==================== <function expand_gbk at 0x7f16b3703940> ====================
# I1222 10:35:17.285218 139737941612416 translations.py:678] ==================== <function sink_flattens at 0x7f16b3703a60> ====================
# I1222 10:35:17.285279 139737941612416 translations.py:678] ==================== <function greedily_fuse at 0x7f16b3703af0> ====================
# I1222 10:35:17.285436 139737941612416 translations.py:678] ==================== <function read_to_impulse at 0x7f16b3703b80> ====================
# I1222 10:35:17.285496 139737941612416 translations.py:678] ==================== <function impulse_to_input at 0x7f16b3703c10> ====================
# I1222 10:35:17.285586 139737941612416 translations.py:678] ==================== <function sort_stages at 0x7f16b3703e50> ====================
# I1222 10:35:17.285676 139737941612416 translations.py:678] ==================== <function setup_timer_mapping at 0x7f16b3703dc0> ====================
# I1222 10:35:17.285749 139737941612416 translations.py:678] ==================== <function populate_data_channel_coders at 0x7f16b3703ee0> ====================
# I1222 10:35:17.286345 139737941612416 statecache.py:172] Creating state cache with size 100
# I1222 10:35:17.286985 139737941612416 worker_handlers.py:889] Created Worker handler <apache_beam.runners.portability.fn_api_runner.worker_handlers.EmbeddedWorkerHandler object at 0x7f16b369acd0> for environment ref_Environment_default_environment_1 (beam:env:embedded_python:v1, b'')
# I1222 10:35:17.287100 139737941612416 fn_runner.py:607] Running (((ref_AppliedPTransform_Create-directory-names-Impulse_3)+(ref_AppliedPTransform_Create-directory-names-FlatMap-lambda-at-core-py-3222-_4))+(ref_AppliedPTransform_Create-directory-names-Map-decode-_6))+(ref_AppliedPTransform_Process-directories_7)
# 2022-12-22 10:35:18.115460: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I1222 10:35:21.339030 139737941612416 interpolator_cli.py:170] Generating in-between frames for /content/gdrive/MyDrive/frame-interpolation/photos.
#   0%|                                                                        | 0/63 [00:00<?, ?it/s]2022-12-22 10:35:32.282966: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.67GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-12-22 10:35:32.283201: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.67GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 100%|███████████████████████████████████████████████████████████████| 63/63 [01:27<00:00,  1.39s/it]
# I1222 10:36:48.883611 139737941612416 interpolator_cli.py:141] Removing existing frames from /content/gdrive/MyDrive/frame-interpolation/photos/interpolated_frames.
# 100%|███████████████████████████████████████████████████████████████| 65/65 [00:13<00:00,  4.86it/s]
# I1222 10:37:02.354010 139737941612416 interpolator_cli.py:149] Output frames saved in /content/gdrive/MyDrive/frame-interpolation/photos/interpolated_frames.
# I1222 10:37:04.308583 139737941612416 interpolator_cli.py:177] Output video saved at /content/gdrive/MyDrive/frame-interpolation/photos/interpolated.mp4.

# %%
#@title ## 補間された動画を表示します。
import mediapy as media
video = media.read_video('photos/interpolated.mp4')
media.show_video(video, fps=30)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="1024" height="768" style="object-fit:cover;" loop autoplay>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
